# %% [markdown]
# # Actividad 2.1
# En este ejercicio vamos a hacer scrapping sobre una página de juegos de mesa para dar un formato más práctico a la información.
#
# En el ejercicio tendrás que programas parte de un código python. En concreto, las partes a programar tienen las siguientes características:
# + Vienen precedidas por el comentario: __########INSERTAR CODIGO AQUI__. Eso quiere decir que la parte a programar será en la línea o líneas inmediatamente inferiores
# + En concreto tendrás que rellenar aquellas partes en las que ponga la  palabra clave __None__ (elimina la palabra None y escribe tu código)
# + Es posible que tengas que contestar a preguntas con texto. Para ello se han habilitado celdas de texto vacías, que podrás rellenar
#
# __Descripción__:
# La página https://boardgamegeek.com/browse/boardgame contiene un ranking de juegos del 1 al 99, pero no nos gusta la forma en la que han organizado la información ya que mezclan en una misma columna del listado el nombre del juego, el año en que salió a la venta y su descripción (en inglés).
#
# Nuestros objetivos van a ser:
# 1. Hacer scraping sobre la página para obtener como resultado un dataframe de pandas (una tabla) que tenga 3 columnas: Name, Year, Description. Este dataframe lo guardaremos en un fichero csv
#
# 2. Hacer un pequeño análisis de los juegos según el año
#
# 3. Hacer un listado de juegos que hablan sobre un tema concreto
#
# 4. (EXTRA) ¿Cómo lo haríamos si quisiéramos hacer el listado de los 1000 primeros juegos?

# %% [markdown]
# #### 1 - Scraping de datos y almacenaje en dataframe
#
# Antes de empezar sería bueno que revisaras en un navegador la página web en la que haremos el scraping (te aconsejo que uses Chrome). Comprueba con el inspector del navegador (botón derecho-Inspect), que realmente la información del nombre, fecha y descripción de cada juego están almacenados en lugares (tags) distintos del html. Una vez hecho esto, vamos a empezar con la práctica.

# %% [markdown]
# * Vamos a empezar importando las librerias de numpy, pandas, matplotlib, requests y BeautifulSoup

# %%
########INSERTAR CODIGO AQUI
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests as rq
from bs4 import BeautifulSoup

# %% [markdown]
# * A continuación definimos en una variable la url que vamos a acceder y usamos la librería requests para hacer una petición, que guardamos en la variable res. Luego revisamos que el estatus de respuesta de la petición es válido

# %%
#Almacenamos la url
########INSERTAR CODIGO AQUI
url = "https://boardgamegeek.com/browse/boardgame"

#Hacemos la petición (usa la variable url)
########INSERTAR CODIGO AQUI
res = rq.get(url)

#Vemos el resultado de la petición
########INSERTAR CODIGO AQUI
print(f'Mi petición a la url {url} ha dado como resultado: {res.status_code}')
# Out:
# Mi petición a la url https://boardgamegeek.com/browse/boardgame ha dado como resultado: 200

# %% [markdown]
# * Ahora vamos a usar BeautifulSoup para parsear el contenido de res. Usa el parser 'html'. Lo guardaremos en la variable soup

# %%
########INSERTAR CODIGO AQUI
soup = BeautifulSoup(res.text, "html.parser")
soup.find('table')
# Out:
# <table cellpadding="0" cellspacing="1" class="collection_table" id="collectionitems" width="100%">
# <tr>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=rank&amp;sortdir=desc">Board Game Rank<img alt="ascending sort" border="0" hspace="5" src="https://cf.geekdo-static.com/images/collection/arrow_up.gif"/></a>
# </th>
# <th class="collection_thumbnail">
# <span class="sr-only">Thumbnail image</span>
# </th>
# <th class="collection_title">
# <a href="/browse/boardgame?sort=title">Title</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=bggrating">Geek Rating</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=avgrating">Avg Rating</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=numvoters">Num Voters</a>
# </th>
# <th class="collection_shop">
# 			Shop
# 		</th>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="1"></a>			1
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/174430/gloomhaven"><img alt="Board Game: Gloomhaven" src="https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname1">
# <div id="status_objectname1"></div>
# <div id="results_objectname1" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/174430/gloomhaven">Gloomhaven</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Vanquish monsters with strategic cardplay. Fulfill your quest to leave your legacy!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.452		</td>
# <td align="center" class="collection_bggrating">
# 			8.68		</td>
# <td align="center" class="collection_bggrating">
# 			53469		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_174430_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="2"></a>			2
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/224517/brass-birmingham"><img alt="Board Game: Brass: Birmingham" src="https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname2">
# <div id="status_objectname2"></div>
# <div id="results_objectname2" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/224517/brass-birmingham">Brass: Birmingham</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build networks, grow industries, and navigate the world of the Industrial Revolution.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.432		</td>
# <td align="center" class="collection_bggrating">
# 			8.65		</td>
# <td align="center" class="collection_bggrating">
# 			32323		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_224517_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="3"></a>			3
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/161936/pandemic-legacy-season-1"><img alt="Board Game: Pandemic Legacy: Season 1" src="https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname3">
# <div id="status_objectname3"></div>
# <div id="results_objectname3" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/161936/pandemic-legacy-season-1">Pandemic Legacy: Season 1</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Mutating diseases are spreading around the world - can your team save humanity?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.417		</td>
# <td align="center" class="collection_bggrating">
# 			8.57		</td>
# <td align="center" class="collection_bggrating">
# 			48314		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_161936_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="4"></a>			4
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/342942/ark-nova"><img alt="Board Game: Ark Nova" src="https://cf.geekdo-images.com/SoU8p28Sk1s8MSvoM4N8pQ__micro/img/LSAi1pmhbTbWwtBrziutDOXzfdY=/fit-in/64x64/filters:strip_icc()/pic6293412.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname4">
# <div id="status_objectname4"></div>
# <div id="results_objectname4" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/342942/ark-nova">Ark Nova</a>
# <span class="smallerfont dull">(2021)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Plan and build a modern, scientifically managed zoo to support conservation projects.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.276		</td>
# <td align="center" class="collection_bggrating">
# 			8.58		</td>
# <td align="center" class="collection_bggrating">
# 			20824		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_342942_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="5"></a>			5
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/233078/twilight-imperium-fourth-edition"><img alt="Board Game: Twilight Imperium: Fourth Edition" src="https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname5">
# <div id="status_objectname5"></div>
# <div id="results_objectname5" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/233078/twilight-imperium-fourth-edition">Twilight Imperium: Fourth Edition</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build an intergalactic empire through trade, research, conquest and grand politics.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.255		</td>
# <td align="center" class="collection_bggrating">
# 			8.65		</td>
# <td align="center" class="collection_bggrating">
# 			18838		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_233078_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="6"></a>			6
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/167791/terraforming-mars"><img alt="Board Game: Terraforming Mars" src="https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname6">
# <div id="status_objectname6"></div>
# <div id="results_objectname6" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/167791/terraforming-mars">Terraforming Mars</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Compete with rival CEOs to make Mars habitable and build your corporate empire.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.249		</td>
# <td align="center" class="collection_bggrating">
# 			8.39		</td>
# <td align="center" class="collection_bggrating">
# 			83813		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_167791_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="7"></a>			7
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/291457/gloomhaven-jaws-lion"><img alt="Board Game: Gloomhaven: Jaws of the Lion" src="https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname7">
# <div id="status_objectname7"></div>
# <div id="results_objectname7" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/291457/gloomhaven-jaws-lion">Gloomhaven: Jaws of the Lion</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Vanquish monsters with strategic cardplay in a 25-scenario Gloomhaven campaign.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.240		</td>
# <td align="center" class="collection_bggrating">
# 			8.56		</td>
# <td align="center" class="collection_bggrating">
# 			23983		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_291457_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="8"></a>			8
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/187645/star-wars-rebellion"><img alt="Board Game: Star Wars: Rebellion" src="https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname8">
# <div id="status_objectname8"></div>
# <div id="results_objectname8" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/187645/star-wars-rebellion">Star Wars: Rebellion</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Strike from your hidden base as the Rebels—or find and destroy it as the Empire.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.169		</td>
# <td align="center" class="collection_bggrating">
# 			8.42		</td>
# <td align="center" class="collection_bggrating">
# 			28208		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_187645_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="9"></a>			9
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/115746/war-ring-second-edition"><img alt="Board Game: War of the Ring: Second Edition" src="https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname9">
# <div id="status_objectname9"></div>
# <div id="results_objectname9" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/115746/war-ring-second-edition">War of the Ring: Second Edition</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			The Fellowship and the Free Peoples clash with Sauron over the fate of Middle-Earth.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.160		</td>
# <td align="center" class="collection_bggrating">
# 			8.52		</td>
# <td align="center" class="collection_bggrating">
# 			17633		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_115746_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="10"></a>			10
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/162886/spirit-island"><img alt="Board Game: Spirit Island" src="https://cf.geekdo-images.com/kjCm4ZvPjIZxS-mYgSPy1g__micro/img/sRPer5FmBxyV527MY67P-gM7ukg=/fit-in/64x64/filters:strip_icc()/pic7013651.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname10">
# <div id="status_objectname10"></div>
# <div id="results_objectname10" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/162886/spirit-island">Spirit Island</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Island Spirits join forces using elemental powers to defend their home from invaders.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.158		</td>
# <td align="center" class="collection_bggrating">
# 			8.37		</td>
# <td align="center" class="collection_bggrating">
# 			39723		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_162886_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="11"></a>			11
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/220308/gaia-project"><img alt="Board Game: Gaia Project" src="https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname11">
# <div id="status_objectname11"></div>
# <div id="results_objectname11" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/220308/gaia-project">Gaia Project</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Expand, research, upgrade, and settle the galaxy with one of 14 alien species.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.157		</td>
# <td align="center" class="collection_bggrating">
# 			8.43		</td>
# <td align="center" class="collection_bggrating">
# 			22498		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_220308_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="12"></a>			12
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/182028/through-ages-new-story-civilization"><img alt="Board Game: Through the Ages: A New Story of Civilization" src="https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname12">
# <div id="status_objectname12"></div>
# <div id="results_objectname12" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/182028/through-ages-new-story-civilization">Through the Ages: A New Story of Civilization</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Rewrite history as you build up your civilization in this epic card drafting game!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.113		</td>
# <td align="center" class="collection_bggrating">
# 			8.34		</td>
# <td align="center" class="collection_bggrating">
# 			28059		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_182028_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="13"></a>			13
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/316554/dune-imperium"><img alt="Board Game: Dune: Imperium" src="https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname13">
# <div id="status_objectname13"></div>
# <div id="results_objectname13" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/316554/dune-imperium">Dune: Imperium</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Influence, intrigue, and combat in the universe of Dune.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.101		</td>
# <td align="center" class="collection_bggrating">
# 			8.35		</td>
# <td align="center" class="collection_bggrating">
# 			26909		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_316554_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="14"></a>			14
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/193738/great-western-trail"><img alt="Board Game: Great Western Trail" src="https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname14">
# <div id="status_objectname14"></div>
# <div id="results_objectname14" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/193738/great-western-trail">Great Western Trail</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Use strategic outposts and navigate danger as you herd your cattle to Kansas City.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.097		</td>
# <td align="center" class="collection_bggrating">
# 			8.26		</td>
# <td align="center" class="collection_bggrating">
# 			36575		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_193738_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="15"></a>			15
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/12333/twilight-struggle"><img alt="Board Game: Twilight Struggle" src="https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname15">
# <div id="status_objectname15"></div>
# <div id="results_objectname15" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/12333/twilight-struggle">Twilight Struggle</a>
# <span class="smallerfont dull">(2005)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Relive the Cold War and rewrite history in an epic clash between the USA and USSR.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.094		</td>
# <td align="center" class="collection_bggrating">
# 			8.26		</td>
# <td align="center" class="collection_bggrating">
# 			45258		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_12333_textwithprices__"></div>
# </td>
# </tr>
# <tr class="geekcollection_ad text-center">
# <td colspan="7">
# <div id="dfp-inline-post_0"></div>
# <script>
# 						 GEEK.legacyAds.push('dfp-inline-post_0');
# 					 </script>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="16"></a>			16
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/169786/scythe"><img alt="Board Game: Scythe" src="https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname16">
# <div id="status_objectname16"></div>
# <div id="results_objectname16" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/169786/scythe">Scythe</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Five factions vie for dominance in a war-torn, mech-filled, dieselpunk 1920s Europe.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.036		</td>
# <td align="center" class="collection_bggrating">
# 			8.19		</td>
# <td align="center" class="collection_bggrating">
# 			72004		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_169786_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="17"></a>			17
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/84876/castles-burgundy"><img alt="Board Game: The Castles of Burgundy" src="https://cf.geekdo-images.com/5CFwjd8zTcGYVUnkXh04hw__micro/img/N1VrEUaW6bmwnqbZfi2nRScwGxM=/fit-in/64x64/filters:strip_icc()/pic1176894.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname17">
# <div id="status_objectname17"></div>
# <div id="results_objectname17" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/84876/castles-burgundy">The Castles of Burgundy</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Plan, trade, and build your Burgundian estate to prosperity and prominence.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.006		</td>
# <td align="center" class="collection_bggrating">
# 			8.13		</td>
# <td align="center" class="collection_bggrating">
# 			55088		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_84876_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="18"></a>			18
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/167355/nemesis"><img alt="Board Game: Nemesis" src="https://cf.geekdo-images.com/tAqLpWxQ0Oo3GaPP3MER1g__micro/img/tivhH093LwCowK-_S7bVF_xha34=/fit-in/64x64/filters:strip_icc()/pic5073276.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname18">
# <div id="status_objectname18"></div>
# <div id="results_objectname18" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/167355/nemesis">Nemesis</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Survive an alien-infested spaceship but beware of other players and their agendas.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.981		</td>
# <td align="center" class="collection_bggrating">
# 			8.33		</td>
# <td align="center" class="collection_bggrating">
# 			23060		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_167355_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="19"></a>			19
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/173346/7-wonders-duel"><img alt="Board Game: 7 Wonders Duel" src="https://cf.geekdo-images.com/zdagMskTF7wJBPjX74XsRw__micro/img/nXtpcw3tYaelntFHb1aH4YrN7Wk=/fit-in/64x64/filters:strip_icc()/pic2576399.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname19">
# <div id="status_objectname19"></div>
# <div id="results_objectname19" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/173346/7-wonders-duel">7 Wonders Duel</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Science? Military? What will you draft to win this head-to-head version of 7 Wonders?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.976		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			78975		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_173346_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="20"></a>			20
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/28720/brass-lancashire"><img alt="Board Game: Brass: Lancashire" src="https://cf.geekdo-images.com/tHVtPzu82mBpeQbbZkV6EA__micro/img/jM8d5Q5btvJmcWQN_px-A-nlueI=/fit-in/64x64/filters:strip_icc()/pic3469216.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname20">
# <div id="status_objectname20"></div>
# <div id="results_objectname20" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/28720/brass-lancashire">Brass: Lancashire</a>
# <span class="smallerfont dull">(2007)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Test your economic mettle as you build and network in the Industrial Revolution.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.966		</td>
# <td align="center" class="collection_bggrating">
# 			8.19		</td>
# <td align="center" class="collection_bggrating">
# 			22427		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_28720_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="21"></a>			21
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/124361/concordia"><img alt="Board Game: Concordia" src="https://cf.geekdo-images.com/CzwSm8i7tkLz6cBnrILZBg__micro/img/FQyxREkHBn7yTbGmBg7c44eLgaM=/fit-in/64x64/filters:strip_icc()/pic3453267.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname21">
# <div id="status_objectname21"></div>
# <div id="results_objectname21" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/124361/concordia">Concordia</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Traders compete to build the greatest empire in the Roman Mediterranean.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.962		</td>
# <td align="center" class="collection_bggrating">
# 			8.11		</td>
# <td align="center" class="collection_bggrating">
# 			35129		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_124361_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="22"></a>			22
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/177736/feast-odin"><img alt="Board Game: A Feast for Odin" src="https://cf.geekdo-images.com/s9oGMCo1fcfV4Dk3EnqLZw__micro/img/JCrcuFDrjVQ64uLbqpH-Pmg6XsU=/fit-in/64x64/filters:strip_icc()/pic3146943.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname22">
# <div id="status_objectname22"></div>
# <div id="results_objectname22" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/177736/feast-odin">A Feast for Odin</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Puzzle together the life of a Viking village as you hunt, farm, craft, and explore.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.952		</td>
# <td align="center" class="collection_bggrating">
# 			8.19		</td>
# <td align="center" class="collection_bggrating">
# 			23704		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_177736_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="23"></a>			23
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/120677/terra-mystica"><img alt="Board Game: Terra Mystica" src="https://cf.geekdo-images.com/bre12I1YiXkZr7elvriz4A__micro/img/SAwaBrDhHbGuq6dFY-ok95qFMcU=/fit-in/64x64/filters:strip_icc()/pic5375624.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname23">
# <div id="status_objectname23"></div>
# <div id="results_objectname23" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/120677/terra-mystica">Terra Mystica</a>
# <span class="smallerfont dull">(2012)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Play fantastical factions.  Expand your influence by terraforming and joining cults.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.942		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			44311		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_120677_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="24"></a>			24
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/266192/wingspan"><img alt="Board Game: Wingspan" src="https://cf.geekdo-images.com/yLZJCVLlIx4c7eJEWUNJ7w__micro/img/5ZaRePVhfelfofF7T_OC1e0gUCw=/fit-in/64x64/filters:strip_icc()/pic4458123.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname24">
# <div id="status_objectname24"></div>
# <div id="results_objectname24" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/266192/wingspan">Wingspan</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Attract a beautiful and diverse collection of birds to your wildlife preserve.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.932		</td>
# <td align="center" class="collection_bggrating">
# 			8.08		</td>
# <td align="center" class="collection_bggrating">
# 			70112		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_266192_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="25"></a>			25
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/266507/clank-legacy-acquisitions-incorporated"><img alt="Board Game: Clank!: Legacy – Acquisitions Incorporated" src="https://cf.geekdo-images.com/hc2NDafu5c24iLJh_IZmyg__micro/img/v2WzacDprYF837E6h9O2WuFFmpw=/fit-in/64x64/filters:strip_icc()/pic4885780.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname25">
# <div id="status_objectname25"></div>
# <div id="results_objectname25" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/266507/clank-legacy-acquisitions-incorporated">Clank!: Legacy – Acquisitions Incorporated</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			"Go forth, be bold, and ACQUIRE!" in this campaign version of "Clank!"
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.932		</td>
# <td align="center" class="collection_bggrating">
# 			8.62		</td>
# <td align="center" class="collection_bggrating">
# 			6931		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_266507_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="26"></a>			26
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/246900/eclipse-second-dawn-galaxy"><img alt="Board Game: Eclipse: Second Dawn for the Galaxy" src="https://cf.geekdo-images.com/Oh3kHw6lweg6ru71Q16h2Q__micro/img/vhB59zFDq3Kul0xbr3api2selZs=/fit-in/64x64/filters:strip_icc()/pic5235277.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname26">
# <div id="status_objectname26"></div>
# <div id="results_objectname26" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/246900/eclipse-second-dawn-galaxy">Eclipse: Second Dawn for the Galaxy</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build an interstellar civilization by exploration, research, conquest, and diplomacy.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.929		</td>
# <td align="center" class="collection_bggrating">
# 			8.56		</td>
# <td align="center" class="collection_bggrating">
# 			8644		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_246900_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="27"></a>			27
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/205637/arkham-horror-card-game"><img alt="Board Game: Arkham Horror: The Card Game" src="https://cf.geekdo-images.com/B5F5ulz0UivNgrI9Ky0euA__micro/img/DnDtwD_7oQR982carXqiVfhOQog=/fit-in/64x64/filters:strip_icc()/pic3122349.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname27">
# <div id="status_objectname27"></div>
# <div id="results_objectname27" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/205637/arkham-horror-card-game">Arkham Horror: The Card Game</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Investigate the horrors of Arkham while courting cosmic doom.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.921		</td>
# <td align="center" class="collection_bggrating">
# 			8.15		</td>
# <td align="center" class="collection_bggrating">
# 			37501		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_205637_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="28"></a>			28
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/237182/root"><img alt="Board Game: Root" src="https://cf.geekdo-images.com/JUAUWaVUzeBgzirhZNmHHw__micro/img/tdHLiMYfi-KTy89sGBGZVeE9ts0=/fit-in/64x64/filters:strip_icc()/pic4254509.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname28">
# <div id="status_objectname28"></div>
# <div id="results_objectname28" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/237182/root">Root</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Decide the fate of the forest as woodland factions fight for contrasting goals.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.896		</td>
# <td align="center" class="collection_bggrating">
# 			8.09		</td>
# <td align="center" class="collection_bggrating">
# 			39148		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_237182_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="29"></a>			29
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/312484/lost-ruins-arnak"><img alt="Board Game: Lost Ruins of Arnak" src="https://cf.geekdo-images.com/6GqH14TJJhza86BX5HCLEQ__micro/img/2FKVaukjh9a-Kg9LWQuMSvLS34s=/fit-in/64x64/filters:strip_icc()/pic5674958.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname29">
# <div id="status_objectname29"></div>
# <div id="results_objectname29" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/312484/lost-ruins-arnak">Lost Ruins of Arnak</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Explore an island to find resources and discover the lost ruins of Arnak.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.882		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			28819		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_312484_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="30"></a>			30
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/164928/orleans"><img alt="Board Game: Orléans" src="https://cf.geekdo-images.com/nagl1li6kYt9elV9jbfVQw__micro/img/hUKCvnqgFvTl0aOMd8FLkgCObT0=/fit-in/64x64/filters:strip_icc()/pic6228507.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname30">
# <div id="status_objectname30"></div>
# <div id="results_objectname30" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/164928/orleans">Orléans</a>
# <span class="smallerfont dull">(2014)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Craftsmen, scholars &amp; monks can help you reign supreme—but who will turn up to help?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.880		</td>
# <td align="center" class="collection_bggrating">
# 			8.07		</td>
# <td align="center" class="collection_bggrating">
# 			27317		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_164928_textwithprices__"></div>
# </td>
# </tr>
# <tr class="geekcollection_ad text-center">
# <td colspan="7">
# <div id="dfp-inline-post_1"></div>
# <script>
# 						 GEEK.legacyAds.push('dfp-inline-post_1');
# 					 </script>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="31"></a>			31
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/199792/everdell"><img alt="Board Game: Everdell" src="https://cf.geekdo-images.com/fjE7V5LNq31yVEW_yuqI-Q__micro/img/TAgkPCJdNAIHZfn1BE1DXadBL9g=/fit-in/64x64/filters:strip_icc()/pic3918905.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname31">
# <div id="status_objectname31"></div>
# <div id="results_objectname31" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/199792/everdell">Everdell</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Gather resources to develop a harmonious village of woodland critters and structures.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.877		</td>
# <td align="center" class="collection_bggrating">
# 			8.07		</td>
# <td align="center" class="collection_bggrating">
# 			38982		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_199792_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="32"></a>			32
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/183394/viticulture-essential-edition"><img alt="Board Game: Viticulture Essential Edition" src="https://cf.geekdo-images.com/l_PRU2lVlX9seScRFcvFlA__micro/img/3EqHlTkNSnZNFHVaAeFSpzfzuIQ=/fit-in/64x64/filters:strip_icc()/pic6500949.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname32">
# <div id="status_objectname32"></div>
# <div id="results_objectname32" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/183394/viticulture-essential-edition">Viticulture Essential Edition</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Create the most prosperous winery in Italy from the Tuscan vineyard you've inherited.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.876		</td>
# <td align="center" class="collection_bggrating">
# 			8.03		</td>
# <td align="center" class="collection_bggrating">
# 			40661		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_183394_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="33"></a>			33
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/96848/mage-knight-board-game"><img alt="Board Game: Mage Knight Board Game" src="https://cf.geekdo-images.com/DUO2hz9AlLOH8p9ED-lCWg__micro/img/eXzdbUmCbIdMIVgiQ_QwS3YNOS4=/fit-in/64x64/filters:strip_icc()/pic1083380.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname33">
# <div id="status_objectname33"></div>
# <div id="results_objectname33" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/96848/mage-knight-board-game">Mage Knight Board Game</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build your hero’s spells, abilities, and artifacts as you explore &amp; conquer cities.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.868		</td>
# <td align="center" class="collection_bggrating">
# 			8.09		</td>
# <td align="center" class="collection_bggrating">
# 			30982		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_96848_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="34"></a>			34
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/251247/barrage"><img alt="Board Game: Barrage" src="https://cf.geekdo-images.com/jEPmWvvYpqkWrKOzqIHFsg__micro/img/Uwm0ZfmY4ZNWWxlackDXrsmS-Io=/fit-in/64x64/filters:strip_icc()/pic4336469.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname34">
# <div id="status_objectname34"></div>
# <div id="results_objectname34" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/251247/barrage">Barrage</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Nations vie for hydroelectric dominance in a dystopia where water is power.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.835		</td>
# <td align="center" class="collection_bggrating">
# 			8.21		</td>
# <td align="center" class="collection_bggrating">
# 			12758		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_251247_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="35"></a>			35
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/175914/food-chain-magnate"><img alt="Board Game: Food Chain Magnate" src="https://cf.geekdo-images.com/Wtxml94LAXsIWQCxGPS63Q__micro/img/4Oucoa190njfSaNHr8YRIl6UnTU=/fit-in/64x64/filters:strip_icc()/pic2649434.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname35">
# <div id="status_objectname35"></div>
# <div id="results_objectname35" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/175914/food-chain-magnate">Food Chain Magnate</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Strategically hire and manage your workforce to outcompete rival fast food chains.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.828		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			17442		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_175914_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="36"></a>			36
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/285774/marvel-champions-card-game"><img alt="Board Game: Marvel Champions: The Card Game" src="https://cf.geekdo-images.com/kRvUgYiaOq07kC67ZK5UoQ__micro/img/4DLQr45lpVBfCkiy-kVwhl4z4vQ=/fit-in/64x64/filters:strip_icc()/pic4900321.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname36">
# <div id="status_objectname36"></div>
# <div id="results_objectname36" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/285774/marvel-champions-card-game">Marvel Champions: The Card Game</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Battle Marvel villains with unique teams of iconic heroes in this LCG.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.817		</td>
# <td align="center" class="collection_bggrating">
# 			8.17		</td>
# <td align="center" class="collection_bggrating">
# 			18395		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_285774_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="37"></a>			37
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/3076/puerto-rico"><img alt="Board Game: Puerto Rico" src="https://cf.geekdo-images.com/QFiIRd2kimaMqTyWsX0aUg__micro/img/ggNIAA1GEadqvcY7Mvwb9_VEybU=/fit-in/64x64/filters:strip_icc()/pic158548.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname37">
# <div id="status_objectname37"></div>
# <div id="results_objectname37" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/3076/puerto-rico">Puerto Rico</a>
# <span class="smallerfont dull">(2002)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Ship goods, construct buildings, and choose roles that benefit you more than others.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.811		</td>
# <td align="center" class="collection_bggrating">
# 			7.94		</td>
# <td align="center" class="collection_bggrating">
# 			67637		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_3076_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="38"></a>			38
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/192135/too-many-bones"><img alt="Board Game: Too Many Bones" src="https://cf.geekdo-images.com/wKwRk0wYBcrtLAfgn4PCdg__micro/img/Q6VXZKoVSlMjTU7Vp8tn1tkcVzw=/fit-in/64x64/filters:strip_icc()/pic6624445.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname38">
# <div id="status_objectname38"></div>
# <div id="results_objectname38" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/192135/too-many-bones">Too Many Bones</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Toss gobs of unique dice in an epic adventure en route to a final boss showdown.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.807		</td>
# <td align="center" class="collection_bggrating">
# 			8.38		</td>
# <td align="center" class="collection_bggrating">
# 			9521		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_192135_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="39"></a>			39
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/102794/caverna-cave-farmers"><img alt="Board Game: Caverna: The Cave Farmers" src="https://cf.geekdo-images.com/rz22tqa5PCYvK9oDjIbvxg__micro/img/sog7ni3vUAAfvd66e6XW4iOca4I=/fit-in/64x64/filters:strip_icc()/pic1790789.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname39">
# <div id="status_objectname39"></div>
# <div id="results_objectname39" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/102794/caverna-cave-farmers">Caverna: The Cave Farmers</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			From a simple cave, expand your dwarven home through mining, agriculture, and more.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.803		</td>
# <td align="center" class="collection_bggrating">
# 			7.98		</td>
# <td align="center" class="collection_bggrating">
# 			31538		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_102794_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="40"></a>			40
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/170216/blood-rage"><img alt="Board Game: Blood Rage" src="https://cf.geekdo-images.com/HkZSJfQnZ3EpS214xtuplg__micro/img/7xdR1_OUo1ReAvYzhi7jBhFMHu0=/fit-in/64x64/filters:strip_icc()/pic2439223.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname40">
# <div id="status_objectname40"></div>
# <div id="results_objectname40" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/170216/blood-rage">Blood Rage</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Ragnarök has come! Secure your place in Valhalla in epic Viking battles.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.796		</td>
# <td align="center" class="collection_bggrating">
# 			7.97		</td>
# <td align="center" class="collection_bggrating">
# 			41520		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_170216_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="41"></a>			41
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/256960/pax-pamir-second-edition"><img alt="Board Game: Pax Pamir: Second Edition" src="https://cf.geekdo-images.com/oSM_AuKYfGIwOtKbVEsoVg__micro/img/SKUliR88eoltB2ytmwz3BffW7aA=/fit-in/64x64/filters:strip_icc()/pic4503733.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname41">
# <div id="status_objectname41"></div>
# <div id="results_objectname41" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/256960/pax-pamir-second-edition">Pax Pamir: Second Edition</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Swing the tides of "The Great Game" as countries vie for control of Afghanistan.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.791		</td>
# <td align="center" class="collection_bggrating">
# 			8.29		</td>
# <td align="center" class="collection_bggrating">
# 			9544		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_256960_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="42"></a>			42
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/324856/crew-mission-deep-sea"><img alt="Board Game: The Crew: Mission Deep Sea" src="https://cf.geekdo-images.com/VuBqZ1sMaDAVVHF_OEJP4g__micro/img/p3GKOrR04nV1qkim9zq-rmFfYh8=/fit-in/64x64/filters:strip_icc()/pic5988903.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname42">
# ...
# <a name="87"></a>			87
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/236457/architects-west-kingdom"><img alt="Board Game: Architects of the West Kingdom" src="https://cf.geekdo-images.com/OAX7HfOz-9N60StgADzd0g__micro/img/5OEOXKjvrEMh2aT5I-FrAn5-9jo=/fit-in/64x64/filters:strip_icc()/pic3781944.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname87">
# <div id="status_objectname87"></div>
# <div id="results_objectname87" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/236457/architects-west-kingdom">Architects of the West Kingdom</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Will you be a virtuous or nefarious servant of the king? Build your way to glory.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.574		</td>
# <td align="center" class="collection_bggrating">
# 			7.78		</td>
# <td align="center" class="collection_bggrating">
# 			24000		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_236457_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="88"></a>			88
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/93/el-grande"><img alt="Board Game: El Grande" src="https://cf.geekdo-images.com/GO282hlXR3RiknU5W4GZjg__micro/img/Ya0GwTP0sOChJ3b0E3Ufmua39gw=/fit-in/64x64/filters:strip_icc()/pic5373572.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname88">
# <div id="status_objectname88"></div>
# <div id="results_objectname88" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/93/el-grande">El Grande</a>
# <span class="smallerfont dull">(1995)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Use your caballeros to control regions of medieval Spain, keeping clear of the King!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.565		</td>
# <td align="center" class="collection_bggrating">
# 			7.74		</td>
# <td align="center" class="collection_bggrating">
# 			25851		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_93_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="89"></a>			89
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/122515/keyflower"><img alt="Board Game: Keyflower" src="https://cf.geekdo-images.com/HbfgxDJZQnNEZQKvpmJxQg__micro/img/L6e_jaWDU2M5XPhV0lMhPPo26EU=/fit-in/64x64/filters:strip_icc()/pic2278942.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname89">
# <div id="status_objectname89"></div>
# <div id="results_objectname89" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/122515/keyflower">Keyflower</a>
# <span class="smallerfont dull">(2012)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Compete in a unique auction system to build the most prosperous village.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.559		</td>
# <td align="center" class="collection_bggrating">
# 			7.75		</td>
# <td align="center" class="collection_bggrating">
# 			21299		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_122515_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="90"></a>			90
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/317985/beyond-sun"><img alt="Board Game: Beyond the Sun" src="https://cf.geekdo-images.com/BfEHqHQAvZLbRX7y7e9TWg__micro/img/RgHc2PFvpz3xxRPRg5v7d46JQNc=/fit-in/64x64/filters:strip_icc()/pic5617866.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname90">
# <div id="status_objectname90"></div>
# <div id="results_objectname90" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/317985/beyond-sun">Beyond the Sun</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Collectively develop a tech tree to fuel the automation and colonization of space.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.556		</td>
# <td align="center" class="collection_bggrating">
# 			7.98		</td>
# <td align="center" class="collection_bggrating">
# 			9408		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_317985_textwithprices__"></div>
# </td>
# </tr>
# <tr class="geekcollection_ad text-center">
# <td colspan="7">
# <div id="dfp-inline-post_5"></div>
# <script>
# 						 GEEK.legacyAds.push('dfp-inline-post_5');
# 					 </script>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="91"></a>			91
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/18602/caylus"><img alt="Board Game: Caylus" src="https://cf.geekdo-images.com/yC7nOSc1x5PT-oNnh6TEcQ__micro/img/R7ZK4KtIIQNR2CJHZ6HtUxEY8ik=/fit-in/64x64/filters:strip_icc()/pic1638795.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname91">
# <div id="status_objectname91"></div>
# <div id="results_objectname91" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/18602/caylus">Caylus</a>
# <span class="smallerfont dull">(2005)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Entrepreneurs pay workers &amp; bribe an official to build a Château &amp; gain royal favor.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.554		</td>
# <td align="center" class="collection_bggrating">
# 			7.74		</td>
# <td align="center" class="collection_bggrating">
# 			28201		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_18602_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="92"></a>			92
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/253344/cthulhu-death-may-die"><img alt="Board Game: Cthulhu: Death May Die" src="https://cf.geekdo-images.com/e8D09pfFsUsoX1D81EeoZg__micro/img/g4fUW30OaTTN48VW7tdVOIAEvWQ=/fit-in/64x64/filters:strip_icc()/pic4705171.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname92">
# <div id="status_objectname92"></div>
# <div id="results_objectname92" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/253344/cthulhu-death-may-die">Cthulhu: Death May Die</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Disrupt the ritual and slay the Elder Gods in this co-op dice chucker.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.554		</td>
# <td align="center" class="collection_bggrating">
# 			8.15		</td>
# <td align="center" class="collection_bggrating">
# 			7972		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_253344_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="93"></a>			93
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/37111/battlestar-galactica-board-game"><img alt="Board Game: Battlestar Galactica: The Board Game" src="https://cf.geekdo-images.com/5Q2w2rFJiFI_uV89KP6ECg__micro/img/KGgAsbHUPaEjsl-r05JCH2ixP1o=/fit-in/64x64/filters:strip_icc()/pic354500.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname93">
# <div id="status_objectname93"></div>
# <div id="results_objectname93" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/37111/battlestar-galactica-board-game">Battlestar Galactica: The Board Game</a>
# <span class="smallerfont dull">(2008)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			How can the human race survive when you don't know who is actually human?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.551		</td>
# <td align="center" class="collection_bggrating">
# 			7.73		</td>
# <td align="center" class="collection_bggrating">
# 			35017		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_37111_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="94"></a>			94
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/172386/mombasa"><img alt="Board Game: Mombasa" src="https://cf.geekdo-images.com/VceWk5QVkgIp6rWDl5qHKQ__micro/img/nHZMadoKR1T5fSg9V6rkR3e39M0=/fit-in/64x64/filters:strip_icc()/pic2611318.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname94">
# <div id="status_objectname94"></div>
# <div id="results_objectname94" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/172386/mombasa">Mombasa</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Acquire shares of unique companies and propagate their trading posts to rake in cash.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.543		</td>
# <td align="center" class="collection_bggrating">
# 			7.87		</td>
# <td align="center" class="collection_bggrating">
# 			12409		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_172386_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="95"></a>			95
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/40834/dominion-intrigue"><img alt="Board Game: Dominion: Intrigue" src="https://cf.geekdo-images.com/OGOmpi0GgwOwH2y28QgkuA__micro/img/VlsgqS2v915vSCwTPVWFVms0-TY=/fit-in/64x64/filters:strip_icc()/pic460011.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname95">
# <div id="status_objectname95"></div>
# <div id="results_objectname95" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/40834/dominion-intrigue">Dominion: Intrigue</a>
# <span class="smallerfont dull">(2009)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Enlist torturers, swindlers, and saboteurs to gain wealth and dominate the kingdom.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.537		</td>
# <td align="center" class="collection_bggrating">
# 			7.70		</td>
# <td align="center" class="collection_bggrating">
# 			32294		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_40834_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="96"></a>			96
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/170042/raiders-north-sea"><img alt="Board Game: Raiders of the North Sea" src="https://cf.geekdo-images.com/hXdfAhgZ8OeyWLunt36wlw__micro/img/qdkWYsmTq_dyuJU5YCVCZMQrkAI=/fit-in/64x64/filters:strip_icc()/pic3578101.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname96">
# <div id="status_objectname96"></div>
# <div id="results_objectname96" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/170042/raiders-north-sea">Raiders of the North Sea</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Gather your Viking crew in order to plunder seas and lands for glory!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.535		</td>
# <td align="center" class="collection_bggrating">
# 			7.76		</td>
# <td align="center" class="collection_bggrating">
# 			20660		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_170042_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="97"></a>			97
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/73439/troyes"><img alt="Board Game: Troyes" src="https://cf.geekdo-images.com/fBIe-aEPtJKC-ceNlspK6A__micro/img/6ZLZgf_o1omV4ijqi2OLJWK_GM0=/fit-in/64x64/filters:strip_icc()/pic750583.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname97">
# <div id="status_objectname97"></div>
# <div id="results_objectname97" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/73439/troyes">Troyes</a>
# <span class="smallerfont dull">(2010)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Defend the city and rise to power by influencing the merchants, knights and clergy.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.535		</td>
# <td align="center" class="collection_bggrating">
# 			7.73		</td>
# <td align="center" class="collection_bggrating">
# 			21589		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_73439_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="98"></a>			98
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/146021/eldritch-horror"><img alt="Board Game: Eldritch Horror" src="https://cf.geekdo-images.com/oxdsZKIX5_3ovDo38EIaeg__micro/img/gx6OxFzIkjvAvXPs8CDcucwwhak=/fit-in/64x64/filters:strip_icc()/pic1872452.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname98">
# <div id="status_objectname98"></div>
# <div id="results_objectname98" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/146021/eldritch-horror">Eldritch Horror</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			An unknown Elder God approaches the world—and you must solve mysteries to stop it.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.532		</td>
# <td align="center" class="collection_bggrating">
# 			7.77		</td>
# <td align="center" class="collection_bggrating">
# 			33536		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_146021_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="99"></a>			99
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/269385/lord-rings-journeys-middle-earth"><img alt="Board Game: The Lord of the Rings: Journeys in Middle-Earth" src="https://cf.geekdo-images.com/1XA2-niwTBa0HEB7hOz3Dw__micro/img/yhbf5YV6KtavOaIVcFC1ZrDQE_0=/fit-in/64x64/filters:strip_icc()/pic4530974.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname99">
# <div id="status_objectname99"></div>
# <div id="results_objectname99" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/269385/lord-rings-journeys-middle-earth">The Lord of the Rings: Journeys in Middle-Earth</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Heroes explore Middle-earth, working together to combat evil in an epic campaign.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.531		</td>
# <td align="center" class="collection_bggrating">
# 			7.96		</td>
# <td align="center" class="collection_bggrating">
# 			13508		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_269385_textwithprices__"></div>
# </td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="100"></a>			100
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/12493/twilight-imperium-third-edition"><img alt="Board Game: Twilight Imperium: Third Edition" src="https://cf.geekdo-images.com/MHeQQrbauUVsvh2QF6PMog__micro/img/qq2rc5GmKHOr8Dpn5Q8di_FD6Cg=/fit-in/64x64/filters:strip_icc()/pic4128153.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname100">
# <div id="status_objectname100"></div>
# <div id="results_objectname100" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/12493/twilight-imperium-third-edition">Twilight Imperium: Third Edition</a>
# <span class="smallerfont dull">(2005)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Epic empire-building game of interstellar conflict, trade, and struggle for power.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.529		</td>
# <td align="center" class="collection_bggrating">
# 			7.81		</td>
# <td align="center" class="collection_bggrating">
# 			18954		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_12493_textwithprices__"></div>
# </td>
# </tr>
# </table>

# %% [markdown]
# * A continuación vamos a crear tres listas en python: lista de nombres de los juegos, lista de años de producción y lista de descripciones. Con estas listas luego generaremos el dataframe
# 1. __Lista de nombres__: mira que tags contienen los nombres y genera una primera lista (te será útil la función __find_all('nombre_tag', class_='nombre_clase_del_tag')__, luego genera una segunda lista vacía, recorre todos los tags de la primera lista y almacena en la segunda lista sólo la información del texto de los nombres

# %%
########INSERTAR CODIGO AQUI
tag_title = soup.find_all('a', class_='primary')
title = []
for tag in tag_title:
    ########INSERTAR CODIGO AQUI
    title.append(tag.text)
print(f'La lista de títulos de juegos es:\n{title}')
# Out:
# La lista de títulos de juegos es:
# ['Gloomhaven', 'Brass: Birmingham', 'Pandemic Legacy: Season 1', 'Ark Nova', 'Twilight Imperium: Fourth Edition', 'Terraforming Mars', 'Gloomhaven: Jaws of the Lion', 'Star Wars: Rebellion', 'War of the Ring: Second Edition', 'Spirit Island', 'Gaia Project', 'Through the Ages: A New Story of Civilization', 'Dune: Imperium', 'Great Western Trail', 'Twilight Struggle', 'Scythe', 'The Castles of Burgundy', 'Nemesis', '7 Wonders Duel', 'Brass: Lancashire', 'Concordia', 'A Feast for Odin', 'Terra Mystica', 'Wingspan', 'Clank!: Legacy – Acquisitions Incorporated', 'Eclipse: Second Dawn for the Galaxy', 'Arkham Horror: The Card Game', 'Root', 'Lost Ruins of Arnak', 'Orléans', 'Everdell', 'Viticulture Essential Edition', 'Mage Knight Board Game', 'Barrage', 'Food Chain Magnate', 'Marvel Champions: The Card Game', 'Puerto Rico', 'Too Many Bones', 'Caverna: The Cave Farmers', 'Blood Rage', 'Pax Pamir: Second Edition', 'The Crew: Mission Deep Sea', 'Agricola', 'Underwater Cities', 'Anachrony', 'Pandemic Legacy: Season 2', 'Mansions of Madness: Second Edition', 'Maracaibo', 'On Mars', 'The Crew: The Quest for Planet Nine', "Tzolk'in: The Mayan Calendar", 'Power Grid', 'Cascadia', 'Crokinole', 'Clans of Caledonia', 'Lisboa', 'Pandemic Legacy: Season 0', 'Star Wars: Imperial Assault', 'Le Havre', 'The Quacks of Quedlinburg', 'Kingdom Death: Monster', 'Mechs vs. Minions', 'Great Western Trail (Second Edition)', 'The Gallerist', 'Paladins of the West Kingdom', 'Android: Netrunner', 'Azul', 'Eclipse', "Aeon's End", 'Race for the Galaxy', 'Kanban EV', 'Through the Ages: A Story of Civilization', 'Clank!: A Deck-Building Adventure', 'The 7th Continent', 'Grand Austria Hotel', 'Five Tribes', 'Fields of Arle', 'Agricola (Revised Edition)', 'Sleeping Gods', 'Teotihuacan: City of Gods', 'Robinson Crusoe: Adventures on the Cursed Island', 'The Voyages of Marco Polo', '7 Wonders', 'Lords of Waterdeep', 'Dominant Species', 'Tainted Grail: The Fall of Avalon', 'Architects of the West Kingdom', 'El Grande', 'Keyflower', 'Beyond the Sun', 'Caylus', 'Cthulhu: Death May Die', 'Battlestar Galactica: The Board Game', 'Mombasa', 'Dominion: Intrigue', 'Raiders of the North Sea', 'Troyes', 'Eldritch Horror', 'The Lord of the Rings: Journeys in Middle-Earth', 'Twilight Imperium: Third Edition']

# %% [markdown]
# 2. __Lista de años__: repetiremos el mismo proceso que con los nombres, pero en este caso haremos unas operaciones extra. Si te fijas los años vienen en el formato (####). Nosotros sólo queremos un número. Así que quitaremos los paréntisis '(' y ')', y convertiremos cada valor de string a entero
#
# __TIP 1__: Se puede eliminar carácteres de un string haciendo __mi_variable_texto.replace('caracter_a_eliminar', '')__
#
# __TIP 2__: Se puede convertir en python una variable de un tipo a otro tipo (casting) de la siguiente forma __tipofinal(variable_en_tipo_inicial)__

# %%
########INSERTAR CODIGO AQUI
tag_year = soup.find_all('span', class_='smallerfont dull')
year = []
for tag in tag_year:
    year_text  = tag.text
    
    #Eliminamos '('
    year_text  = year_text.replace('(', '')
    
    #Eliminamos ')' y convertimos a string
    year_text  = year_text.replace(')', '')
    year_number = int(year_text)
    
    year.append(year_number)
    
print(f'La lista de años de juegos es:\n{year}')
# Out:
# La lista de años de juegos es:
# [2017, 2018, 2015, 2021, 2017, 2016, 2020, 2016, 2011, 2017, 2017, 2015, 2020, 2016, 2005, 2016, 2011, 2018, 2015, 2007, 2013, 2016, 2012, 2019, 2019, 2020, 2016, 2018, 2020, 2014, 2018, 2015, 2011, 2019, 2015, 2019, 2002, 2017, 2013, 2015, 2019, 2021, 2007, 2018, 2017, 2017, 2016, 2019, 2020, 2019, 2012, 2004, 2021, 1876, 2017, 2017, 2020, 2014, 2008, 2018, 2015, 2016, 2021, 2015, 2019, 2012, 2017, 2011, 2016, 2007, 2020, 2006, 2016, 2017, 2015, 2014, 2014, 2016, 2021, 2018, 2012, 2015, 2010, 2012, 2010, 2019, 2018, 1995, 2012, 2020, 2005, 2019, 2008, 2015, 2009, 2015, 2010, 2013, 2019, 2005]

# %% [markdown]
# 3. __Lista de descripciones__: repetiremos el mismo proceso que con los nombres y los años. En este caso quitaremos los carácteres de salto de línea y de tabulación '\n' y '\t'

# %%
########INSERTAR CODIGO AQUI
tag_description = soup.find_all('p', class_='smallefont dull')
description = []
for tag in tag_description:
    description_text = tag.text
    
    #Eliminamos los carácteres '\n' y '\t'
    description_text = description_text.replace('\n', '')
    description_text = description_text.replace('\t', '')
    
    description.append(description_text)

print(f'La lista de descripciones es:\n{description}')
# Out:
# La lista de descripciones es:
# ['Vanquish monsters with strategic cardplay. Fulfill your quest to leave your legacy!', 'Build networks, grow industries, and navigate the world of the Industrial Revolution.', 'Mutating diseases are spreading around the world - can your team save humanity?', 'Plan and build a modern, scientifically managed zoo to support conservation projects.', 'Build an intergalactic empire through trade, research, conquest and grand politics.', 'Compete with rival CEOs to make Mars habitable and build your corporate empire.', 'Vanquish monsters with strategic cardplay in a 25-scenario Gloomhaven campaign.', 'Strike from your hidden base as the Rebels—or find and destroy it as the Empire.', 'The Fellowship and the Free Peoples clash with Sauron over the fate of Middle-Earth.', 'Island Spirits join forces using elemental powers to defend their home from invaders.', 'Expand, research, upgrade, and settle the galaxy with one of 14 alien species.', 'Rewrite history as you build up your civilization in this epic card drafting game!', 'Influence, intrigue, and combat in the universe of Dune.', 'Use strategic outposts and navigate danger as you herd your cattle to Kansas City.', 'Relive the Cold War and rewrite history in an epic clash between the USA and USSR.', 'Five factions vie for dominance in a war-torn, mech-filled, dieselpunk 1920s Europe.', 'Plan, trade, and build your Burgundian estate to prosperity and prominence.', 'Survive an alien-infested spaceship but beware of other players and their agendas.', 'Science? Military? What will you draft to win this head-to-head version of 7 Wonders?', 'Test your economic mettle as you build and network in the Industrial Revolution.', 'Traders compete to build the greatest empire in the Roman Mediterranean.', 'Puzzle together the life of a Viking village as you hunt, farm, craft, and explore.', 'Play fantastical factions.  Expand your influence by terraforming and joining cults.', 'Attract a beautiful and diverse collection of birds to your wildlife preserve.', '"Go forth, be bold, and ACQUIRE!" in this campaign version of "Clank!"', 'Build an interstellar civilization by exploration, research, conquest, and diplomacy.', 'Investigate the horrors of Arkham while courting cosmic doom.', 'Decide the fate of the forest as woodland factions fight for contrasting goals.', 'Explore an island to find resources and discover the lost ruins of Arnak.', 'Craftsmen, scholars & monks can help you reign supreme—but who will turn up to help?', 'Gather resources to develop a harmonious village of woodland critters and structures.', "Create the most prosperous winery in Italy from the Tuscan vineyard you've inherited.", 'Build your hero’s spells, abilities, and artifacts as you explore & conquer cities.', 'Nations vie for hydroelectric dominance in a dystopia where water is power.', 'Strategically hire and manage your workforce to outcompete rival fast food chains.', 'Battle Marvel villains with unique teams of iconic heroes in this LCG.', 'Ship goods, construct buildings, and choose roles that benefit you more than others.', 'Toss gobs of unique dice in an epic adventure en route to a final boss showdown.', 'From a simple cave, expand your dwarven home through mining, agriculture, and more.', 'Ragnarök has come! Secure your place in Valhalla in epic Viking battles.', 'Swing the tides of "The Great Game" as countries vie for control of Afghanistan.', 'Dive into the deep sea in this co-operative trick-taking game.', "Build your farmstead by sowing fields and raising livestock. But don't forget to eat!", 'Develop future cities on the seafloor through politics, production, and science.', 'Use Exosuits & time travel to ensure your vision for the future after the cataclysm.', 'The world is a mystery after a devastating pandemic—where will your team go?', 'Unravel mysteries in Arkham with your investigative team in this app-guided game.', 'Seafarers journey to obtain wealth and fame in the 17th century Caribbean.', 'Be a par ...

# %% [markdown]
# * Finalmente vamos a crear un dataframe de pandas (variable df), a partir de las 3 listas anteriores, cuyas columnas tendrán como encabezados 'Title', 'Year', 'Description'. Lo guardamos en un csv
#
# __TIP 1__: Recuerda que se puede crear un dataframe a partir de listas de datos de distintas formas. En el curso lo hemos visto definiendo un diccionario en python (cuyas entradas son el nombre de la columna y la lista de datos asociada)
#
# __TIP 2__: Los diccionarios en python se definen como __{'nombre_1': variable1, 'nombre2': variable2, ...}__

# %%
########INSERTAR CODIGO AQUI
df = pd.DataFrame({'Title':title, 'Year':year, 'Description':description})
display(df)
# Out:
#                                               Title  Year  \
# 0                                        Gloomhaven  2017
# 1                                 Brass: Birmingham  2018
# 2                         Pandemic Legacy: Season 1  2015
# 3                                          Ark Nova  2021
# 4                 Twilight Imperium: Fourth Edition  2017
# ..                                              ...   ...
# 95                         Raiders of the North Sea  2015
# 96                                           Troyes  2010
# 97                                  Eldritch Horror  2013
# 98  The Lord of the Rings: Journeys in Middle-Earth  2019
# 99                 Twilight Imperium: Third Edition  2005
#
#                                           Description
# 0   Vanquish monsters with strategic cardplay. Ful...
# 1   Build networks, grow industries, and navigate ...
# 2   Mutating diseases are spreading around the wor...
# 3   Plan and build a modern, scientifically manage...
# 4   Build an intergalactic empire through trade, r...
# ..                                                ...
# 95  Gather your Viking crew in order to plunder se...
# 96  Defend the city and rise to power by influenci...
# 97  An unknown Elder God approaches the world—and ...
# 98  Heroes explore Middle-earth, working together ...
# 99  Epic empire-building game of interstellar conf...
#
# [100 rows x 3 columns]

# %%
########INSERTAR CODIGO AQUI
nombre_alumno_sin_espacios='Damaris_Daniela'
apellido_alumno_sin_espacios='Nunez_Perez'


df.to_csv('lista_juegos_'+nombre_alumno_sin_espacios+'_'+apellido_alumno_sin_espacios+'.csv')

# %% [markdown]
# #### 2 - Pequeño análisis de los juegos según el año

# %% [markdown]
# * Ahora que ya tenemos nuestro dataframe de pandas, vamos a analizar los datos en función de los años. Para empezar miramos la información de nuestro dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        100 non-null    object
#  1   Year         100 non-null    int64
#  2   Description  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %% [markdown]
# --> En la siguiente celda (celda de texto) escribe brevemente qué información útil hemos conseguido al hacer .info(). ¿Cuántas muestras tenemos? ¿Cuántas columnas? ¿De qué tipo los datos en cada columna?
#
# __A CONTINUACIÓN CELDA A RELLENAR POR EL ALUMNO__

# %% [markdown]
# Tenemos un total de 100 muestras, 3 columnas donde los tipos de columna son:
# - tipo objeto la columna Title
# - tipo entero (int64) la columna Year
# - tipo objeto la columna Description

# %% [markdown]
# * Puesto que la columna 'Year' es la única numérica, vamos a trabajarla un poco. Para empezar, vamos a ver de forma numérica cuántos años distintos hay, y cuántos juegos se han producido en esos años:
#
# 1. Accede a la columna 'Year', y usa la función __value_counts()__ de pandas para generar una tabla (otro dataframe) de años y juegos por año
#
# 2. Cuenta cuántos años distintos hay, que se corresponde con el número de filas de la tabla que hemos creado antes
#
# __TIP__: para saber las dimensiones de un dataframe podemos usar __df.shape__, o bien __df.shape[0]__, __df.shape[1]__ para alguna dimensión en concreto

# %%
#Accedemos a la columna 'Year' y contamos valores
########INSERTAR CODIGO AQUI
juegos_por_año = df['Year'].value_counts()

display(juegos_por_año)
# Out:
# 2015    12
# 2017    11
# 2019    11
# 2016    11
# 2018     8
# 2020     8
# 2012     6
# 2021     5
# 2011     4
# 2014     4
# 2005     3
# 2007     3
# 2013     3
# 2010     3
# 2008     2
# 2002     1
# 2004     1
# 1876     1
# 2006     1
# 1995     1
# 2009     1
# Name: Year, dtype: int64

# %%
#Miramos en la variable anterior el número de años (número de filas)
########INSERTAR CODIGO AQUI
num_años_distintos = juegos_por_año.count()

print(f'Hay un total de {num_años_distintos} años distintos\n')
# Out:
# Hay un total de 21 años distintos

# %% [markdown]
# * Vamos a extraer un array de numpy con todos los años y luego almacenaremos en sendas variables el año del juego más antiguo y el año del juego más moderno
#
# __TIP 1__: para convertir una columna de pandas a un array de numpy, podemos usar la función __.to_numpy()__
#
# __TIP 2__: En numpy tenemos funciones rápidas para sacar el máximo o el mínimo valor de un array

# %%
#Extraemos un array con todos los años
########INSERTAR CODIGO AQUI
year_array = df['Year'].to_numpy()

#Guardamos el año máximo y el mínimo en dos variables
########INSERTAR CODIGO AQUI
min_year = year_array.min()
max_year = year_array.max()

print(f'Año del juego más antiguo: {min_year}')
print(f'Año del juego más actual: {max_year}')
# Out:
# Año del juego más antiguo: 1876
# Año del juego más actual: 2021

# %% [markdown]
# * A continuación, vamos a mostrar todos los datos relativos al juego más antiguo. Lo haremos en 2 pasos:
# 1. Buscaremos en el array de numpy cuál es el índice (posición) correspondiente al juego más antiguo (puedes usar la función __argmin()__ de numpy)
# 2. En el dataframe de todos los datos, buscaremos por índice la fila correspondiente a ese juego (revisa cómo se acceden a filas concretas de un dataframe)

# %%
#Extracción del índice del juego más antiguo
########INSERTAR CODIGO AQUI
position_min_year = year_array.argmin()

#Extracción de los datos del juego más antiguo
########INSERTAR CODIGO AQUI
complete_row_min_year = df.loc[position_min_year]

print(f"El juego más antiguo es:\n{complete_row_min_year}")
# Out:
# El juego más antiguo es:
# Title                                                  Crokinole
# Year                                                        1876
# Description    Flick discs and make trick shots in this tradi...
# Name: 53, dtype: object

# %% [markdown]
# * Para finalizar nuestro análisis, vamos a visualizar el histograma de distribución de juegos por años
# Para ello usaremos la visualización __hist__ de matplotlib sobre el array de años. Como parámetro adicional al histograma le daremos el rango de años que queremos visualizar en el parámetro bins: __hist(xxx, bins=rango_años)__
#
# __TIP 1__: Ejemplo. Si tuviéramos datos entre 1900 y 1800, entonces rango_años = 100

# %%
#Calculamos el rango de años de los datos (¿puedes usar variables que ya hemos creado?)
########INSERTAR CODIGO AQUI
years_range = max_year - min_year

#Mostramos la gráfica de barras del histograma con matplotlib
plt.figure(figsize=(10,5))
plt.grid()
########INSERTAR CODIGO AQUI
plt.hist(year_array, bins=years_range)

#Le añadimos un título, una etiqueta de eje X y una de eje Y a nuestra gráfica
########INSERTAR CODIGO AQUI
plt.title("Juegos por año")
plt.xlabel("Años")
plt.ylabel("Número de juegos")
# Out:
# Text(0, 0.5, 'Número de juegos')

# %% [markdown]
# __Pregunta__: ¿Crees que estamos visualizando bien la mayoría de los datos? ¿Crees que se podría eliminar algún outlier para luego visualizar los datos mejor? Responde brevemente en la siguiente celda.
#
# __A CONTINUACIÓN CELDA A RELLENAR POR EL ALUMNO__

# %% [markdown]
# Creemos que no se estan observando de la mejor manera, ya que una ves obtenido el grafico podemos ver que existen una muestra muy alejada de las demás por lo que puede ser considerado ruido, por lo que es preferible eliminarlo, de esta manera podremos tener una visualización más limpia y amplia de los resultados ya que el rago del eje y se reduce.

# %% [markdown]
# * Vamos a repetir la visualización anterior, pero eliminando el dato que hayamos identificado como outlier, para que la visualización quede más clara. Para ello seguiremos 3 pasos
#
# 1. Eliminaremos del dataframe de datos la fila correspondiente al outlier. Para ello usaremos la función de pandas __.drop(indice_fila_a_eliminar, inplace = False)__. El resultado se almacenara en un dataframe nuevo
# 2. Convertimos la columna 'Year' del nuevo dataframe (sin el outlier) a numpy y calculamos sobre el array de años el nuevo rango de años
# 3. Mostramos la gráfica de histograma sobre el array creado y usando el parámetro bins=nuevo_rango_años

# %%
#Creamos un dataframe eliminando la fila del outlier
########INSERTAR CODIGO AQUI
df_without_outlier = df.drop(position_min_year, inplace = False)

#Calculamos el nuevo rango de años
year_array_without_outlier = df_without_outlier['Year'].to_numpy()
max_year_without_outlier = np.max(year_array_without_outlier)
min_year_without_outlier = np.min(year_array_without_outlier)

years_range_without_outlier = max_year_without_outlier - min_year_without_outlier + 1

#Mostramos el histograma sobre los datos sin outlier
plt.figure(figsize=(10,5))
plt.grid()
########INSERTAR CODIGO AQUI
plt.hist(year_array_without_outlier, bins=years_range_without_outlier)
plt.title('Histograma de juegos por año')
plt.xlabel('Año')
plt.ylabel('Número de juegos')
# Out:
# Text(0, 0.5, 'Número de juegos')

# %% [markdown]
# __Pregunta__: ¿Crees que ha mejorado la visualización? ¿Por qué? Responde brevemente en la siguiente celda.
#
# __A CONTINUACIÓN CELDA A RELLENAR POR EL ALUMNO__

# %% [markdown]
# Sí, ha mejorado bastante, ya que podemos ver los datos con un rango en y más pequeño lo cual nos premite observar más intervalos en el eje anteriormente mencionado y de esta manera podemos analizar los datos de mejor manera.

# %% [markdown]
# #### 3 - Extracción de información a partir de los datos
# Vamos a concluir esta actividad con un rápido ejercicio de extracción de información. Supongamos que sólo estoy interesado en juegos que de forma directa tengan la __temática de aliens__. Seguiremos los siguientes pasos
# 1. Extraemos la columna que más información nos vaya a dar para nuestro objetivo
# 2. Definimos la palabra clave 'alien' y miramos qué filas contienen esa palabra
# 3. Mostramos en pantalla el resultado
#
# __TIP 1__: Para buscar una palabra clave en una columna de tipo texto en pandas, podemos usar la función __columna.str.contains(palabra_clave)__. Esta será nuestra condición de filtrado del dataframe
#
# __TIP 2__: Para filtrar un dataframe y quedarnos sólo con ciertas columnas podemos usar la siguiente expresión, df[condicion_de_filtrado]

# %%
#Extraemos la columna interesante
########INSERTAR CODIGO AQUI
relevant_column = df['Description']

#Definimos la palabra clave y nuestra condición de filtrado
########INSERTAR CODIGO AQUI
keyword = 'alien'
condition = relevant_column.str.contains(keyword)

#Creamos un dataframe filtrado con la información relevante
########INSERTAR CODIGO AQUI
df_only_alien_games = df[condition]

print('Los juegos que hablan directamente de aliens son:\n')
display(df_only_alien_games)
# Out:
# Los juegos que hablan directamente de aliens son:
#            Title  Year                                        Description
# 10  Gaia Project  2017  Expand, research, upgrade, and settle the gala...
# 17       Nemesis  2018  Survive an alien-infested spaceship but beware...
# 68    Aeon's End  2016  Mages defend humanity’s last city, harnessing ...

# %% [markdown]
# #### 4 (EXTRA) - Ampliar el número de juegos (datos)
# Este apartado es opcional. No es imprescindible rellenarlo para acabar la actividad, pero se valorará positivamente si se rellena.
#
# En este apartado no hay código, sólo una pregunta a responder: __¿Si hubiéramos querido nuestro dataset tuviera no 100 juegos, sino 1000, se te ocurre una forma rápida de hacerlo?__
#
# Razona tu respuesta en la siguiente celda. Puedes escribir pseudocódigo, pero no hace falta que sea funcional
#
# __TIP 1:__ si tenemos dos dataframes, los podemos concatenar con la función __pd.concat(lista_de_dataframes, ignore_index= True)__
#
# __A CONTINUACIÓN CELDA A RELLENAR POR EL ALUMNO__

# %% [markdown]
# Podríamos haber indexado los datos de las demás páginas de la pagina web, ya que con la url unicamente tomo los 100 registros que escontraban en la página 1.

# %% [markdown]
# ```
# url = "https://boardgamegeek.com/browse/boardgame"
# res = rq.get(url)
# soup = BeautifulSoup(res.text, "html.parser")
# soup.find('a', title_='last page')
# soup.find('table')
# ## repetir el proceso realizado para crear el data friend
# cont = 1
# while(numero_registros < 1000){
#     url = url +'/page/' + cont
#     res = rq.get(url)
#     soup = BeautifulSoup(res.text, "html.parser")
#     ##generar los arrays de las columnas
#     cont = cont + 1
# }
# ##generar el nuevo data frame
# ##concatenar con el primer data frame
# pd.concat(nuevo_dataframe, ignore_index= True)
# ```
